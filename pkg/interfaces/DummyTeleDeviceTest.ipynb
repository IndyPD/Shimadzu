# %%
from teleop_server_vive import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from teleop_server_vive import *
#
# File D:\INDY_TEST\TeleOpPack\interfaces\teleop_server_vive.py:8
#       5 sys.path.append(os.path.join(os.path.dirname(__file__), '..'))
#       6 sys.path.append(os.path.join(os.path.dirname(__file__), 'impl'))
# ----> 8 import grpc
#       9 from concurrent import futures
#      10 from control_socket_client import ControlSocketClient
#
# ModuleNotFoundError: No module named 'grpc'

# %% [markdown]
# ## Server Test

# %%
server = grpc.server(futures.ThreadPoolExecutor(max_workers=10),
                     options=
                     [('grpc.max_send_message_length', 10 * 1024 * 1024),
                      ('grpc.max_receive_message_length', 10 * 1024 * 1024)]
                     )
servicer = TeleOpDeviceServicer()
teleop_grpc.add_TeleOpDeviceServicer_to_server(servicer=servicer, server=server)

server.add_insecure_port('[::]:{}'.format(DEVICE_PORT))
server.start()

# %% [markdown]
# ## Client Test

# %%
_channel = grpc.insecure_channel("{}:{}".format('192.168.8.184', DEVICE_PORT))
_stub = teleop_grpc.TeleOpDeviceStub(_channel)

# %%
_stub.StartTeleOpStream(teleop_data.TeleOpStreamReq(ip_indy='192.168.0.105', port=20001))
# Out:
# StartTeleOpStream to 192.168.0.105:20001
# StopTeleOpStream to 192.168.0.105

# %%
_stub.StopTeleOpStream(teleop_data.Empty())
# Out:
# StopTeleOpStream to 192.168.0.105
