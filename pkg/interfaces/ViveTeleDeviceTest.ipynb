# %%
import os
os.chdir("..")

# %%
# !pip install pyModbusTCP

# %%
from interfaces.teleop_server_vive import *

# %% [markdown]
# ## Server Test

# %%
server = grpc.server(futures.ThreadPoolExecutor(max_workers=10))
servicer = TeleOpDeviceServicer()
teleop_grpc.add_TeleOpDeviceServicer_to_server(servicer=servicer, server=server)

server.add_insecure_port('[::]:{}'.format(DEVICE_PORT))
server.start()
# Out:
# Found 2 Tracking References
#   tracking_reference_1 (LHB-E744E381, Mode Valve SR Imp, Valve SR Imp)
#   tracking_reference_2 (LHB-E56DDC9F, Mode Valve SR Imp, Valve SR Imp)
# Found 1 HMD
#   hmd_1 (LHR-51E862CA, VIVE_Pro MV)
# Found 0 Controllers
# Found 1 Tracker
#   tracker_1 (LHR-99FA16A8, VIVE Tracker 3.0 MV)

# %%
# server.wait_for_termination()

# %%
servicer.get_vive_pose()

# %% [markdown]
# ## Client Test

# %%
_channel = grpc.insecure_channel("{}:{}".format('192.168.0.124', DEVICE_PORT))
_stub = teleop_grpc.TeleOpDeviceStub(_channel)

# %%
_stub.StartTeleOpStream(teleop_data.TeleOpStreamReq(ip_indy='192.168.0.144', port=20001))

# %%
_stub.StopTeleOpStream(teleop_data.Empty())

# %%
servicer.get_vive_pose()

# %%
# !pip install protobuf==3.17.3
